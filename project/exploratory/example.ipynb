# %% [markdown]
# # Exploration (Jupyter)
#
# Exploration only — nothing here is load-bearing. `nbstripout` removes outputs
# before commit so diffs stay clean and no data/credentials leak into git. Promote
# anything real into `src/` + a Snakemake rule.

# %%
# from <package> import theming
1 + 1
